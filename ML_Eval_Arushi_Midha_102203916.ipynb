# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Fuel_cell_performance_data-Full.csv')
df.head()
# Out:
#      F1    F2    F3     F4      F5    F6     F7     F8   F9   F10      F11  \
# 0  52.9  1.33  49.1  37.13  129.43  35.0  0.281  112.7  207  0.55   98.971
# 1  87.6  2.12  48.8  42.10  171.07  37.6  0.153  157.4  188  0.86  101.179
# 2  73.3  2.72  93.8  20.11  163.69  44.3  0.367  348.7  270  1.87   98.919
# 3  65.6  2.58  48.1  35.11   63.37  32.5  0.279  321.2  322  1.75  101.560
# 4  39.6  2.58  49.3  32.93   63.40  47.0  0.149  205.6  203  1.55   98.148
#
#     F12   F13   F14   F15  Target1  Target2  Target3  Target4  Target5
# 0  2.87  1362  15.9   429    0.959    1.531     79.3     4.19    33.29
# 1  2.34  5130  26.1  1819    0.728    1.690     57.2     5.19    34.50
# 2  2.13  7811  16.7  1763    0.784    1.865     61.6     7.77   129.28
# 3  2.91  1641  32.1   203    0.884    1.920     71.3     8.40   186.65
# 4  1.93  7648  27.5   276    0.736    1.711     58.5     4.75    52.32

# %%
df = df.drop(['Target1', 'Target3', 'Target4', 'Target5'], axis=1)

# %%
from pycaret.regression import *

# %%
s = setup(data=df, target='Target2',train_size = 0.7)
# Out:
# <style type="text/css">
# #T_a8c59_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a8c59" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8c59_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a8c59_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8c59_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8c59_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a8c59_row0_col1" class="data row0 col1" >3160</td>
#     </tr>
#     <tr>
#       <th id="T_a8c59_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8c59_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a8c59_row1_col1" class="data row1 col1" >Target2</td>
#     </tr>
#     <tr>
#       <th id="T_a8c59_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
cm=compare_models()
# Out:
# <style type="text/css">
# #T_3a404 th {
#   text-align: left;
# }
# ...

# %%
print(cm)
# Out:
# BayesianRidge()

# %%
evaluate_model(cm)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
evaluate_model(cm)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
